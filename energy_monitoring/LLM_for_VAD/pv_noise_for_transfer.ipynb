# %%
import os
import cv2
import numpy as np

def add_gaussian_noise(image, mean=0, var=10):
    """Adds Gaussian noise to an image."""
    sigma = var ** 0.5
    gauss = np.random.normal(mean, sigma, image.shape)
    noisy_image = image + gauss
    noisy_image = np.clip(noisy_image, 0, 255)  # Ensure pixel values are valid
    return noisy_image.astype(np.uint8)

def process_images(input_folder, output_folder, noise_var=10):
    """Processes all images in a folder by adding Gaussian noise and saving the result."""
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    for filename in os.listdir(input_folder):
        if filename.endswith(".png") or filename.endswith(".jpg") or filename.endswith(".jpeg"):
            img_path = os.path.join(input_folder, filename)
            image = cv2.imread(img_path)
            
            if image is not None:
                noisy_image = add_gaussian_noise(image, var=noise_var)
                
                output_path = os.path.join(output_folder, filename)
                cv2.imwrite(output_path, noisy_image)
                print(f"Processed and saved: {output_path}")
            else:
                print(f"Failed to load image: {img_path}")

input_folders = ['./Faulty_solar_panel/test/0',
                 './Faulty_solar_panel/test/1-Bird-drop',
                 './Faulty_solar_panel/test/2-Dusty',
                 './Faulty_solar_panel/test/3-Snow-Covered',
                 './Faulty_solar_panel/test/4-Electrical-damage',
                 './Faulty_solar_panel/test/5-Physical-Damage']


output_folders = ['./Faulty_solar_panel/transfer/0',
                 './Faulty_solar_panel/transfer/1-Bird-drop',
                 './Faulty_solar_panel/transfer/2-Dusty',
                 './Faulty_solar_panel/transfer/3-Snow-Covered',
                 './Faulty_solar_panel/transfer/4-Electrical-damage',
                 './Faulty_solar_panel/transfer/5-Physical-Damage']

noise_variance = 10000

for i in range(len(input_folders)):
    process_images(input_folders[i], output_folders[i], noise_var=noise_variance)
# Out:
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/0/Clean (178).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/0/Clean (193).png
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/0/Clean (189).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/0/Clean (188).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/0/Clean (174).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/0/Clean (183).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/0/Clean (186).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/0/Clean (191).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/0/Clean (181).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/0/Clean (177).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/0/Clean (180).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/0/Clean (187).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/0/Clean (175).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/0/Clean (179).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/0/Clean (184).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/0/Clean (192).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/0/Clean (176).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/0/Clean (182).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/0/Clean (185).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/0/Clean (190).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/1-Bird-drop/Bird (194).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/1-Bird-drop/Bird (182).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/1-Bird-drop/Bird (189).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/1-Bird-drop/Bird (184).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/1-Bird-drop/Bird (180).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/1-Bird-drop/Bird (193).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/1-Bird-drop/Bird (195).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/1-Bird-drop/Bird (186).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/1-Bird-drop/Bird (188).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/1-Bird-drop/Bird (192).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/1-Bird-drop/Bird (183).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/1-Bird-drop/Bird (197).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/1-Bird-drop/Bird (187).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/1-Bird-drop/Bird (191).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/1-Bird-drop/Bird (196).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/1-Bird-drop/Bird (190).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/1-Bird-drop/Bird (181).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/1-Bird-drop/Bird (185).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/2-Dusty/Dust (175).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/2-Dusty/Dust (186).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/2-Dusty/Dust (172).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/2-Dusty/Dust (184).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/2-Dusty/Dust (181).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/2-Dusty/Dust (183).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/2-Dusty/Dust (176).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/2-Dusty/Dust (189).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/2-Dusty/Dust (185).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/2-Dusty/Dust (171).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/2-Dusty/Dust (182).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/2-Dusty/Dust (179).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/2-Dusty/Dust (188).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/2-Dusty/Dust (178).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/2-Dusty/Dust (177).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/2-Dusty/Dust (173).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/2-Dusty/Dust (174).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/2-Dusty/Dust (187).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/2-Dusty/Dust (190).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/2-Dusty/Dust (180).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/3-Snow-Covered/Snow (110).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/3-Snow-Covered/Snow (105).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/3-Snow-Covered/Snow (113).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/3-Snow-Covered/Snow (104).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/3-Snow-Covered/Snow (109).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/3-Snow-Covered/Snow (123).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/3-Snow-Covered/Snow (117).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/3-Snow-Covered/Snow (115).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/3-Snow-Covered/Snow (120).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/3-Snow-Covered/Snow (116).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/3-Snow-Covered/Snow (111).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/3-Snow-Covered/Snow (121).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/3-Snow-Covered/Snow (114).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/3-Snow-Covered/Snow (106).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/3-Snow-Covered/Snow (112).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/3-Snow-Covered/Snow (107).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/3-Snow-Covered/Snow (122).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/3-Snow-Covered/Snow (119).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/3-Snow-Covered/Snow (108).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/3-Snow-Covered/Snow (118).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/4-Electrical-damage/Electrical (81).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/4-Electrical-damage/Electrical (92).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/4-Electrical-damage/Electrical (82).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/4-Electrical-damage/Electrical (98).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/4-Electrical-damage/Electrical (90).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/4-Electrical-damage/Electrical (84).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/4-Electrical-damage/Electrical (96).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/4-Electrical-damage/Electrical (94).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/4-Electrical-damage/Electrical (80).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/4-Electrical-damage/Electrical (97).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/4-Electrical-damage/Electrical (88).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/4-Electrical-damage/Electrical (95).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/4-Electrical-damage/Electrical (83).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/4-Electrical-damage/Electrical (87).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/4-Electrical-damage/Electrical (99).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/4-Electrical-damage/Electrical (89).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/4-Electrical-damage/Electrical (91).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/4-Electrical-damage/Electrical (93).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/5-Physical-Damage/Physical (67).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/5-Physical-Damage/Physical (62).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/5-Physical-Damage/Physical (58).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/5-Physical-Damage/Physical (53).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/5-Physical-Damage/Physical (55).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/5-Physical-Damage/Physical (69).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/5-Physical-Damage/Physical (59).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/5-Physical-Damage/Physical (61).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/5-Physical-Damage/Physical (50).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/5-Physical-Damage/Physical (66).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/5-Physical-Damage/Physical (60).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/5-Physical-Damage/Physical (64).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/5-Physical-Damage/Physical (54).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/5-Physical-Damage/Physical (68).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/5-Physical-Damage/Physical (57).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/5-Physical-Damage/Physical (63).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/5-Physical-Damage/Physical (65).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/5-Physical-Damage/Physical (51).jpg
# Processed and saved: /root/LLM/GPT4V/Faulty_solar_panel/transfer/5-Physical-Damage/Physical (56).jpg
